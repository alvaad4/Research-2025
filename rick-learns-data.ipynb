# %%
import re
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



#initialize data frame
columns = ['total duration','load duration', 'prompt eval count', 'prompt eval duration','prompt eval rate','eval count','eval duration','eval rate']
rows = []

pattern = r'\s\d+.?\d+'

with open(r"C:\Users\rickt\Downloads\text1.txt", 'r') as file:
    for line in file:
        print(line)
        pattern = r"\s(\d+m)?(\d+(\.?\d+)?)"
        result = re.search(pattern, line)
        result = result.groups()
        if result[0] != None:
            rows.append(result[0]*60 + result[1])
        else:
            rows.append(result[1])

print(rows)


#readlines, feed int othe reg expression, if there is mins, mult by 60 and add, then add that to the dataframe, if no mins, just add the secions into the dataframe

# matches = re.findall(pattern, content)





# df = pd.DataFrame(rows, columns=columns)
# print(df)
# Out:
# total duration:       4.175484246s
#
# load duration:        36.669776ms
#
# prompt eval count:    16 token(s)
#
# prompt eval duration: 86.158192ms
#
# prompt eval rate:     185.70 tokens/s
#
# eval count:           48 token(s)
#
# eval duration:        4.052233416s
#
# eval rate:            11.85 tokens/s
#
# total duration:       2.83066848s
#
# load duration:        37.467608ms
#
# prompt eval count:    38 token(s)
#
# prompt eval duration: 708.925162ms
#
# prompt eval rate:     53.60 tokens/s
#
# eval count:           25 token(s)
#
# eval duration:        2.083790511s
#
# eval rate:            12.00 tokens/s
#
# total duration:       21.202907893s
#
# load duration:        38.496037ms
#
# prompt eval count:    40 token(s)
#
# prompt eval duration: 746.302332ms
#
# prompt eval rate:     53.60 tokens/s
#
# eval count:           232 token(s)
#
# eval duration:        20.417698322s
#
# eval rate:            11.36 tokens/s
#
# total duration:       7.47741603s
#
# load duration:        37.168773ms
#
# prompt eval count:    32 token(s)
#
# prompt eval duration: 670.896921ms
#
# prompt eval rate:     47.70 tokens/s
#
# eval count:           78 token(s)
#
# eval duration:        6.769007293s
#
# eval rate:            11.52 tokens/s
#
# total duration:       12.162052326s
#
# load duration:        56.497719ms
#
# prompt eval count:    24 token(s)
#
# prompt eval duration: 480.22984ms
#
# prompt eval rate:     49.98 tokens/s
#
# eval count:           133 token(s)
#
# eval duration:        11.624934502s
#
# eval rate:            11.44 tokens/s
#
# total duration:       19.461214432s
#
# load duration:        37.572201ms
#
# prompt eval count:    22 token(s)
#
# prompt eval duration: 438.898331ms
#
# prompt eval rate:     50.13 tokens/s
#
# eval count:           216 token(s)
#
# eval duration:        18.984412013s
#
# eval rate:            11.38 tokens/s
#
# total duration:       46.403514532s
#
# load duration:        36.547454ms
#
# prompt eval count:    21 token(s)
#
# prompt eval duration: 419.589603ms
#
# prompt eval rate:     50.05 tokens/s
#
# eval count:           516 token(s)
#
# eval duration:        45.946994531s
#
# eval rate:            11.23 tokens/s
#
# total duration:       4.436162761s
#
# load duration:        36.550354ms
#
# prompt eval count:    19 token(s)
#
# prompt eval duration: 362.823836ms
#
# prompt eval rate:     52.37 tokens/s
#
# eval count:           47 token(s)
#
# eval duration:        4.036359737s
#
# eval rate:            11.64 tokens/s
#
# total duration:       5.436755418s
#
# load duration:        39.982107ms
#
# prompt eval count:    26 token(s)
#
# prompt eval duration: 541.881371ms
#
# prompt eval rate:     47.98 tokens/s
#
# eval count:           56 token(s)
#
# eval duration:        4.854422703s
#
# eval rate:            11.54 tokens/s
#
# total duration:       21.359703119s
#
# load duration:        36.13002ms
#
# prompt eval count:    16 token(s)
#
# prompt eval duration: 305.271101ms
#
# prompt eval rate:     52.41 tokens/s
#
# eval count:           238 token(s)
#
# eval duration:        21.017941969s
#
# eval rate:            11.32 tokens/s
#
# total duration:       16.076264637s
#
# load duration:        40.088017ms
#
# prompt eval count:    50 token(s)
#
# prompt eval duration: 1.113888368s
#
# prompt eval rate:     44.89 tokens/s
#
# eval count:           171 token(s)
#
# eval duration:        14.921857148s
#
# eval rate:            11.46 tokens/s
#
# total duration:       6.850157987s
#
# load duration:        38.549176ms
#
# prompt eval count:    15 token(s)
#
# prompt eval duration: 277.685682ms
#
# prompt eval rate:     54.02 tokens/s
#
# eval count:           76 token(s)
#
# eval duration:        6.533537824s
#
# eval rate:            11.63 tokens/s
#
# total duration:       1m47.414877428s
#
# load duration:        36.549063ms
#
# prompt eval count:    41 token(s)
#
# prompt eval duration: 923.462479ms
#
# prompt eval rate:     44.40 tokens/s
#
# eval count:           1178 token(s)
#
# eval duration:        1m46.454514933s
#
# eval rate:            11.07 tokens/s
#
#     * **Assess the Damage:** Theyâ€™ll evaluate the extent of the broken glass.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 19
#      17 pattern = r"\s(\d+m)?(\d+(\.?\d+)?)"
#      18 result = re.search(pattern, line)
# ---> 19 result = result.groups()
#      20 if result[0] != None:
#      21     rows.append(result[0]*60 + result[1])
#
# AttributeError: 'NoneType' object has no attribute 'groups'

# %%
import re

text = ' 6.34235235s'
pattern = r'\s(\d+m)?(\d+(\.?\d+)?)'
result = re.search(pattern, text)
result.groups()
# Out:
# <re.Match object; span=(0, 11), match=' 6.34235235'>
